# %% [markdown]
# # Hill House Object Data from the National Trust for Scotland
#
# Data analysis for Spring 2018 Design with Data course

# %%
import pandas as pd
df = pd.read_csv("HillHouse.csv")
df.head()
# Out:
#      DwD    record_type  number_of_parts            object_category  \
# 0    2.1  single object              1.0  Furniture and Furnishings
# 1    2.2            set              7.0  Furniture and Furnishings
# 2  2.2.1  single object              1.0  Furniture and Furnishings
# 3  2.2.2  single object              1.0  Furniture and Furnishings
# 4  2.2.3  single object              1.0  Furniture and Furnishings
#
#   object_name title                                        description  \
# 0   Fireplace   NaN  A stained dark oak fireplace with coloured gla...
# 1  Shelf Unit   NaN  A set of seven units, consisting of two cupboa...
# 2  Shelf Unit   NaN  One of a set of seven units. A dark stained oa...
# 3    Cupboard   NaN  One of a set of seven units. A dark oak staine...
# 4  Shelf Unit   NaN  One of a set of seven units. A dark stained oa...
#
#   material.part condition.part                     creator  \
# 0           NaN            NaN  Mackintosh, Charles Rennie
# 1           NaN            NaN  Mackintosh, Charles Rennie
# 2           NaN            NaN  Mackintosh, Charles Rennie
# 3           NaN            NaN  Mackintosh, Charles Rennie
# 4           NaN            NaN  Mackintosh, Charles Rennie
#
#                          ...                         creator.role  \
# 0                        ...                             Designer
# 1                        ...                             Designer
# 2                        ...                             Designer
# 3                        ...                             Designer
# 4                        ...                             Designer
#
#   production.place   production.period production.date.start  \
# 0              NaN  Early 20th century                  1903
# 1              NaN                 NaN                   NaN
# 2              NaN                 NaN                   NaN
# 3              NaN                 NaN                   NaN
# 4              NaN                 NaN                   NaN
#
#   production.date.start.prec production.date.end production.date.end.prec  \
# 0                        NaN                1903                      NaN
# 1                        NaN                 NaN                      NaN
# 2                        NaN                 NaN                      NaN
# 3                        NaN                 NaN                      NaN
# 4                        NaN                 NaN                      NaN
#
#   part_of_reference parts_reference  \
# 0               NaN             NaN
# 1               NaN           2.2.1
# 2               2.2             NaN
# 3               2.2             NaN
# 4               2.2             NaN
#
#                                     current_location
# 0                               Hill House / Library
# 1  Hill House / See Separate Records for Location...
# 2                               Hill House / Library
# 3                               Hill House / Library
# 4                               Hill House / Library
#
# [5 rows x 21 columns]

# %%
print(df['record_type'].unique())
print(len(df['record_type'].unique()))
# Out:
# ['single object' 'set' 'group']
# 3

# %% [markdown]
# What's the difference between a 'set' and a 'group' for record_type?

# %%
print(df['number_of_parts'].unique())
print(len(df['number_of_parts'].unique()))
# Out:
# [  1.   7.   2.   4.   3.  nan  12.   8.   5.  20.]
# 10

# %%
print(df['object_category'].unique())
print(len(df['object_category'].unique()))
# Out:
# ['Furniture and Furnishings' 'Fire and Fireplace' 'Decorative Arts'
#  'Lighting' 'Cooking, Dining and Drinking' 'Photography'
#  'Household Textiles' 'Paintings, Drawings and Prints' 'Toiletry'
#  'Miscellaneous' 'Jewellery' 'Horology' 'Needlework and Tapestries' nan
#  'Costume' 'Sculpture']
# 16

# %%
print(df['object_name'].unique())
print(len(df['object_name'].unique()))
print(df.shape)
# Out:
# ['Fireplace' 'Shelf Unit' 'Cupboard' 'Mantel Border' 'Easy Armchair' 'Box'
#  'Fender' 'Fire Iron' 'Plate' 'Taper Box' 'Tobacco Box' 'Candle Sconce'
#  'Candlestick' 'Liqueur Cup' 'Bougie Box' 'Chestnut Roaster'
#  'Photographic Print' 'Armchair' 'Table' 'Window Seat' 'Seat Cover'
#  'Standard Lamp' 'Lamp Shade' 'Stool' 'Grand Piano' 'Key' 'Poker' 'Tongs'
#  'Wall Light' 'Carpet' 'Curtain' 'Towel Rail' 'Dining Table'
#  'Longcase Clock' 'Open Armchair' 'Side Chair' 'Sideboard' 'Tray'
#  'Wall Sconce' 'Bowl' 'Plate Warmer' 'Jug' 'Fruit Stand' 'Glass'
#  'Ceiling Light' 'Portrait' 'Miniature Chair' 'Napkin' 'Skirt' 'Blouse'
#  'Hat' 'Antimacassar' 'Light-Fitting' 'Garden Bench' 'Hall Chair'
#  'Hall Clock' 'Hanging Light' 'Rug' 'Print' 'Kettle' 'Bed' 'Brush' 'Ewer'
#  'Bedspread' 'Fire Surround' 'Couch' 'Wardrobe' 'Chair' 'Mirror'
#  'Dressing Table' 'Fitted Wardrobe' 'Washstand' 'Centre Light' 'Basin'
#  'Centre Stool' 'Coffee-cup' 'Saucer' 'Porringer' 'Tureen' 'Lid'
#  'Sauce Boat' 'Cabinet' 'Vase' 'Vacuum Cleaner' 'Bag' 'Pipe' 'Nozzle'
#  'Ashet' 'Dinner-service' 'Canister' 'Storage Jar' 'Pie Dish' 'Jar' 'Dish'
#  'Meat Plate' 'Bread Bin' 'Meat Roaster' 'Cannister' 'Letter-opener'
#  'Painting' 'Drawings' 'Drawing' 'Pencil Drawing' 'Dining Chair'
#  'Preserving Pan' 'Cooking Pot' 'Jelly Mould' 'Shovel' 'Desk' 'Cushion'
#  'Panel' 'Footboard' 'Fireplace Furniture' 'Bookplate' 'Letter' 'Tankard'
#  'Lamp' 'Watercolour' 'Inkwell' 'Coffee-set' 'Hair Brush' 'Perfume Bottle'
#  'Single Bed' 'Bed Spread' 'Mat' 'Griddle' 'Baking Bowl' 'Bell Board'
#  'Coffee Mill' 'Bucket' 'Electric Fire' 'Carpet Sweeper' 'Necklace'
#  'Dining Chairs' 'Dressing Stool' 'Bedside Table' 'Bench' 'Pan' 'Fire-iron'
#  'Wall Clock' 'Tea-cup' 'Spoon' 'Tenderiser' 'Butter Hand' 'Butter Scoop'
#  'Scoop' 'Sauce Tureen' 'Serving Dish' 'Side Plate' 'Flour Sifter'
#  'Pastry Cutter' 'Tin' 'Egg Rack' 'Rolling Pin' 'Potato Masher'
#  'Serving Spoon' 'Spurtle' 'Butter pat' 'Wall Cupboard' 'Bookcase'
#  'Side Cabinet' 'Mantel Clock' 'Alcove' 'Sponge' 'Loofah' 'Sheet'
#  'Writing Desk' 'Fire Guard' 'Wallpaper' 'Tea Cosy' 'Feather' 'Fragment'
#  'Towel' 'Sample' 'Ribbon' 'Tray Cloth' 'Sink' 'Cistern' 'Toilet' 'Plaque'
#  'Fabric' 'Roasting Tin' 'Toilet Seat' 'Cutter' 'Spatula' 'Grater'
#  'Strainer' 'Spicerack' 'Ladder' 'Telephone' 'Basket' 'Sculpture']
# 192
# (851, 21)

# %% [markdown]
# Object names are not unique (there are 192 names for 851 records)

# %%
print(df['title'].unique())
print(len(df['title'].unique()))
# Out:
# [nan 'Walter Blackie' 'Sunset, Largo' 'The Cumbrae from Portencross'
#  'The Manor House Abbotsbury Dorsetshire' 'Mrs Younger' 'Elizabeth Dryden'
#  'Sleeping Princess' 'In the Garden of the Hill House'
#  'Five Open Rectangles in Space']
# 10

# %%
print(df['material.part'].unique())
print(len(df['material.part'].unique()))
# Out:
# [nan 'frame' 'stand' 'Whole' 'Panel' 'Case' 'Frame' 'Lamp' 'Handle'
#  'Canister' 'Cannister' 'Jar' 'Body' 'Upholestery' 'Board' 'Bucket'
#  'Overall' 'Cupboard' 'Drawing' 'Bag' 'Loop' 'Ladder' 'Basket']
# 23

# %%
print(df['condition.part'].unique())
print(len(df['condition.part'].unique()))
# Out:
# [nan 'Whole' 'Board']
# 3

# %%
print(df['creator'].unique())
print(len(df['creator'].unique()))
# Out:
# ['Mackintosh, Charles Rennie' nan 'Craig, John' 'Jack, William'
#  'Broadwood, John & Sons' 'John Broadwood & Sons' 'Avena Carpets'
#  'Mitchell, Alexander' 'Spinks & Co.' 'Royal Worcester' 'Strain, Hilary'
#  'National Trust for Scotland' 'John Blacksmith, Allan' 'Morris, Talwyn'
#  'Templetons' 'Martin, Alex' 'Mackintosh, Margaret Macdonald'
#  'Bulpitt & Sons' 'W. Thomson, Hatter & Glover' 'Younger, Jane'
#  'Royal Crown Derby' 'G. T. M.' 'William Adams and Sons Ltd' 'Cauldon Ltd'
#  'Figgjo' 'Copeland and Garrett' 'Dresser, Christopher' 'Hoover Company'
#  'Keeling & Co.' 'Gordon B. Bros' 'Copeland Spode' 'Grimwade' 'Hartley'
#  'Wedgwood' 'Eismarck' 'Pringle, John Quinton' 'Judge Ware'
#  'Grosvenor Eagle Pottery Glasgow' 'Hilliard, Terence' 'Henry, George'
#  'Adams, W. S. & Son' 'J. Moyes' 'Kayserzinn' 'Dallas, Mr'
#  "Dr Gemmell's mother" 'Raeburn, Henry (FRSE, RA)' 'Blackie, Alison'
#  'Fergusson, John Duncan' 'Gray F Portobello' 'Ewbank' 'Heathcote China'
#  'Furnival' 'Steelite' 'Haviland & Co Limoges' 'Helpmate' 'Tala'
#  'Tala Cookware' 'MacDonald, Margaret' 'Liberty & Co.' 'William McClymont'
#  'Cockburn J F' 'Rickey, George']
# 62

# %%
print(df['creator.role'].unique())
print(len(df['creator.role'].unique()))
# Out:
# ['Designer' nan 'Maker' 'Artist' 'Manufacturer' 'Author']
# 6

# %%
print(df['production.place'].unique())
print(len(df['production.place'].unique()))
# Out:
# [nan 'Arundel, Sussex, England' 'Halifax' 'Gorbals'
#  'Gorbals, Glasgow, Scotland' 'London' 'Cramond House' 'Glasgow'
#  'Birmingham' 'Edinburgh' 'Fife' 'Tunstall' 'England' 'Burslem'
#  'Gloucester' 'Stoke-on-Trent' 'Staffordshire' 'Derby' 'Bristol'
#  '57 Haymarket' 'Denmark']
# 21

# %%
print(df['production.period'].unique())
print(len(df['production.period'].unique()))
print()
print(df['production.date.start'].unique())
print(len(df['production.date.start'].unique()))
print()
print(df['production.date.end'].unique())
print(len(df['production.date.end'].unique()))
print()

import numpy as np
# Turn date strings into integers
strStartDates = list(df['production.date.start'])
startDates = []
for date in strStartDates:
    #print(type(date))
    if type(date) is str:
        if date == '1902-07':
            intDate = 1902
        else:
            intDate = int(date)
        startDates += [intDate]
print("Earliest and Latest Start Dates")
print(np.min(startDates))
print(np.max(startDates))
print()
strEndDates = list(df['production.date.end'])
endDates = []
for date in strEndDates:
    if type(date) is str:
        if date == '1902-07':
            intDate = 1907
        else:
            intDate = int(date)
        endDates += [intDate]
print("Earliest and Latest End Dates")
print(np.min(endDates))
print(np.max(endDates))
# Out:
# ['Early 20th century' nan 'Late 19th century' '20th century'
#  'Early 19th century' 'Mid-Georgian' 'Mid-18th century' '19th century'
#  'Late Victorian' 'Mid-20th century' 'Late 20th century' 'Mid-19th century'
#  'Late 19th-Early 20th century']
# 13
#
# ['1903' nan '1870' '1900' '1905' '1904' '1925' '1908' '1910' '1811' '1780'
#  '1740' '1800' '1837' '1928' '1957' '1983' '1984' '1912' '1986' '1902'
#  '1930' '1913' '1833' '1887' '1902-07' '1992' '1920' '1830' '1924' '1815'
#  '1894' '1980' '1858' '1996']
# 35
#
# ['1903' nan '1899' '1929' '1999' '1905' '1904' '1930' '1908' '1910' '1837'
#  '1790' '1769' '1900' '1901' '1928' '1957' '1983' '1984' '1912' '1986'
#  '1902' '1915' '1969' '1913' '1847' '1887' '1902-07' '1992' '1920' '1869'
#  '1926' '1815' '1949' '1894' '1980' '1858' '1996']
# 38
#
# Earliest and Latest Start Dates
# 1740
# 1996
#
# Earliest and Latest End Dates
# 1769
# 1999

# %% [markdown]
# One of the dates was a range, so I split the range into start date 1902 and end date 1907.

# %%
print(df['current_location'].unique())
print(len(df['current_location'].unique()))
# Out:
# ['Hill House / Library'
#  'Hill House / See Separate Records for Locations of Parts'
#  'Hill House / Drawing Room' "Hill House / Daughter's Bedroom"
#  'Hill House / Attic' 'Hill House / Dining Room'
#  'Hill House / Linen Cupboard A / Silver Strong Room / Shelf 1'
#  "Hill House / Butler's Pantry"
#  'Hill House / Upper Hall / Silver Strong Room / Linen Cupboard A / Shelf 6'
#  'Hill House / Upper Hall / Linen Cupboard A / Shelf 2'
#  'Hill House / Upper Hall / Linen Cupboard A / Shelf 3'
#  'Hill House / Upper Hall / Linen Cupboard A / Shelf 1'
#  'Hill House / Night Nursery' 'Hill House / Lower Hall'
#  'Hill House / Upper Hall' 'Hill House / Bathroom'
#  'Hill House / Dressing Room'
#  'Hill House / Dressing Room / Chest of Drawers'
#  'Hill House / White Bedroom'
#  'Hill House / Flower Pantry / Cupboard 2017.4032.4'
#  'Hill House / Flower Pantry / Cupboard 2017.4032.1'
#  'Hill House / Flower Pantry / Cupboard 2017.4032.2'
#  'Hill House / Flower Pantry' 'Hill House / Kitchen'
#  'Hill House / Kitchen / Cupboard 2017.4034'
#  'Hill House / Room off Tea Room' 'Hill House / Staircase / Upper Hall'
#  'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 3'
#  'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 5'
#  'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 2'
#  'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 4'
#  'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 1'
#  'Hill House / Upper Hall / Linen Cupboard A / Shelf 4'
#  'Holidays / Hill House' 'Hill House / Guest Bedroom'
#  'Hill House / Main Stair'
#  'Hill House / Upper Hall / Linen Cupboard B / Drawer 4'
#  'Hill House / Upper Hall / Linen Cupboard B / Drawer 5'
#  'Hill House / Cloakroom']
# 39

# %% [markdown]
# # Data to export to WordWanderer
# http://wordwanderer.org/

# %%
desc_list = df['description']
assert len(desc_list == df.shape[0]), "There should be one description for every row in the data"

# %%
import csv
with open('objectDescriptions.csv', 'wt') as csvfile:
    w = csv.writer(csvfile)
    w.writerows(desc_list.items())

# %% [markdown]
# # Data to export for prototyping
#
# Creator, ID (so we can link to the object’s picture), Object Name, Object Description, Start Date (4 digit year), Location

# %%
df.columns
# Out:
# Index(['DwD', 'record_type', 'number_of_parts', 'object_category',
#        'object_name', 'title', 'description', 'material.part',
#        'condition.part', 'creator', 'creator.qualifier', 'creator.role',
#        'production.place', 'production.period', 'production.date.start',
#        'production.date.start.prec', 'production.date.end',
#        'production.date.end.prec', 'part_of_reference', 'parts_reference',
#        'current_location'],
#       dtype='object')

# %%
sub_df = pd.DataFrame( { 'ID' : df.loc[:, 'DwD'], 'object_category' : df.loc[:, 'object_category'], 'object_name' : df.object_name, 'description' : df.description, 'creator' : df.creator, 'production_place' : df.loc[:, 'production.place'], 'production_date_start' : df.loc[:, 'production.date.start'], 'production_date_end' : df.loc[:, 'production.date.end'], 'current_location' : df.current_location })
sub_df.tail()
# Out:
#               ID         creator  \
# 846      2017.42             NaN
# 847    2017.4245  Rickey, George
# 848    2017.4247             NaN
# 849  2017.4248.1             NaN
# 850  2017.4248.2             NaN
#
#                                       current_location  \
# 846                         Hill House / Flower Pantry
# 847                             Hill House / Cloakroom
# 848                       Hill House / Butler's Pantry
# 849  Hill House / Upper Hall / Linen Cupboard B / D...
# 850  Hill House / Upper Hall / Linen Cupboard B / D...
#
#                                            description  \
# 846  An oval wicker flower basket with a round hand...
# 847  Sections of an outdoor stainless steel kinetic...
# 848  A ceramic salt glaze storage jar with a raised...
# 849  One of a set of two curtains in cream cotton, ...
# 850  One of a set of two curtains in cream cotton, ...
#
#                   object_category  object_name production_date_end  \
# 846                 Miscellaneous       Basket                1929
# 847                     Sculpture    Sculpture                1996
# 848  Cooking, Dining and Drinking  Storage Jar                1929
# 849            Household Textiles      Curtain                 NaN
# 850            Household Textiles      Curtain                 NaN
#
#     production_date_start production_place
# 846                  1900              NaN
# 847                  1996              NaN
# 848                  1900              NaN
# 849                   NaN              NaN
# 850                   NaN              NaN

# %%
sub_df.shape
# Out:
# (851, 9)

# %%
end_date_list = list(sub_df.production_date_end)
new_end_dates = []
#type(end_date_list[850])
#print(end_date_list[850])
for d in end_date_list:
    if type(d) == float:
        d = '0000'
    d = str(d)
    if d == '1902-07':
        d = '1907'
    new_end_dates += [d]
    
for new_d in new_end_dates:
    assert type(new_d) == str, "All new dates should be strings"
    assert len(new_d) == 4, "All new dates should be 4 digit years"

# %%
start_date_list = list(sub_df.production_date_start)
new_start_dates = []
for sd in start_date_list:
    if type(sd) == float:
        sd = '0000'
    sd = str(sd)
    if sd == '1902-07':
        sd = '1902'
    new_start_dates += [sd]
    
for new_sd in new_start_dates:
    assert type(new_sd) == str, "All new dates should be strings"
    assert len(new_sd) == 4, "All new dates should be 4 digit years"

# %%
assert len(new_end_dates) == len(new_start_dates), "There should be the same number of start and end dates"

# %%
creator_list = list(sub_df.creator)
new_creators = []
for c in creator_list:
    if type(c) == float:
        c = 'Unknown'
    new_creators += [c]

for new_c in new_creators:
    assert type(new_c) == str, "All new creators should be strings"

# %%
place_list = list(sub_df.production_place)
new_places = []
for p in place_list:
    if type(p) == float:
        p = 'Unknown'
    new_places += [p]
    
for new_p in new_places:
    assert type(new_p) == str, "All new dates should be strings"

# %%
sub_df = pd.DataFrame( { 'ID' : df.loc[:, 'DwD'], 'object_category' : df.loc[:, 'object_category'], 'object_name' : df.object_name, 'description' : df.description, 'creator' : new_creators, 'production_place' : new_places, 'production_date_start' : new_start_dates, 'production_date_end' : new_end_dates, 'current_location' : df.current_location })
sub_df.head()
# Out:
#       ID                     creator  \
# 0    2.1  Mackintosh, Charles Rennie
# 1    2.2  Mackintosh, Charles Rennie
# 2  2.2.1  Mackintosh, Charles Rennie
# 3  2.2.2  Mackintosh, Charles Rennie
# 4  2.2.3  Mackintosh, Charles Rennie
#
#                                     current_location  \
# 0                               Hill House / Library
# 1  Hill House / See Separate Records for Location...
# 2                               Hill House / Library
# 3                               Hill House / Library
# 4                               Hill House / Library
#
#                                          description  \
# 0  A stained dark oak fireplace with coloured gla...
# 1  A set of seven units, consisting of two cupboa...
# 2  One of a set of seven units. A dark stained oa...
# 3  One of a set of seven units. A dark oak staine...
# 4  One of a set of seven units. A dark stained oa...
#
#              object_category object_name production_date_end  \
# 0  Furniture and Furnishings   Fireplace                1903
# 1  Furniture and Furnishings  Shelf Unit                0000
# 2  Furniture and Furnishings  Shelf Unit                0000
# 3  Furniture and Furnishings    Cupboard                0000
# 4  Furniture and Furnishings  Shelf Unit                0000
#
#   production_date_start production_place
# 0                  1903          Unknown
# 1                  0000          Unknown
# 2                  0000          Unknown
# 3                  0000          Unknown
# 4                  0000          Unknown

# %%
import csv
sub_df.to_csv('clean_data.csv')

# %%
known_places = []
for pl in new_places:
    if pl != "Unknown":
        known_places += [pl]

# %%
print(len(known_places))
# Out:
# 161

# %%
for i in range(0, 20):
    print(known_places[i])
# Out:
# Arundel, Sussex, England
# Arundel, Sussex, England
# Halifax
# Gorbals
# Gorbals, Glasgow, Scotland
# Gorbals, Glasgow, Scotland
# Gorbals, Glasgow, Scotland
# London
# Cramond House
# Cramond House
# Cramond House
# Glasgow
# Glasgow
# Glasgow
# Birmingham
# Birmingham
# Birmingham
# Edinburgh
# Fife
# Tunstall

# %%
for row in sub_df.itertuples():
    if row[-1] != 'Unknown':
        print(row)
        print()
# Out:
# Pandas(Index=32, ID='2.26.1', creator='Jack, William', current_location='Hill House / Drawing Room', description='A white painted wooden window seat. The seat has a rectangular padded back above cushioned seats and rests on square supports flanked on either side by rectangular columns. The rectangular columns are headed by stylised flowerheads each carved with four rectangular medallions. The sides of the seat are fitted with three open book divisions. The seat is upholersted with straw coloured hessian and decorated with a pink rose stencil. The whole is reconstructed based on the original.', object_category='Furniture and Furnishings', object_name='Window Seat', production_date_end='1903', production_date_start='1903', production_place='Arundel, Sussex, England')
#
# Pandas(Index=33, ID='2.26.2', creator='Jack, William', current_location="Hill House / Daughter's Bedroom", description='A seat cover for the window seat in the Hill House Drawing Room. The seat cover has a brown hessian backing with a stencilled cube border running around three edges and on the main body there is a stencilled stylised rose and leaf motif in pink and green.', object_category='Furniture and Furnishings', object_name='Seat Cover', production_date_end='1903', production_date_start='1903', production_place='Arundel, Sussex, England')
#
# Pandas(Index=50, ID='2.41', creator='Avena Carpets', current_location='Hill House / Drawing Room', description='A reproduction beige wool carpet with pink and fawn squares.', object_category='Household Textiles', object_name='Carpet', production_date_end='1999', production_date_start='1900', production_place='Halifax')
#
# Pandas(Index=59, ID='2.53', creator='Mitchell, Alexander', current_location='Hill House / See Separate Records for Locations of Parts', description='A longcase clock and a set of two keys.', object_category='Furniture and Furnishings', object_name='Longcase Clock', production_date_end='1790', production_date_start='1780', production_place='Gorbals')
#
# Pandas(Index=60, ID='2.53.1', creator='Mitchell, Alexander', current_location='Hill House / Dining Room', description='A mahogany longcase clock. The clock has a broken pediment above an arched glazed door enclosing a brass dial with silvered chapter ring and subsidiary seconds dial with date aperture inscribed in the arch. The case is fitted with a rectangular trunk door with shaped apron on bracket feet. Above the face of the clock is a round brass plaque engaved "Alex Mitchel Gorbals." The clock face is metal with black dials and sits on a gilded relief decoration of botanics and marine life. On top of the case there is a scrolled carved wood decoration with an urn in the centre.', object_category='Furniture and Furnishings', object_name='Longcase Clock', production_date_end='1790', production_date_start='1780', production_place='Gorbals, Glasgow, Scotland')
#
# Pandas(Index=61, ID='2.53.2', creator='Mitchell, Alexander', current_location='Hill House / Dining Room', description='A key for the longcase clock. The key is brass and has a circular handle with a tip, a flat straight body and cylindrical end with a square hole pierced. This could possibly be the key to wind the longcase clock.', object_category='Furniture and Furnishings', object_name='Key', production_date_end='1790', production_date_start='1780', production_place='Gorbals, Glasgow, Scotland')
#
# Pandas(Index=62, ID='2.53.3', creator='Mitchell, Alexander', current_location='Hill House / Dining Room', description='A key for the longcase clock. The key is made of white metal and has an oval handle with a cylindrical body.', object_category='Furniture and Furnishings', object_name='Key', production_date_end='1790', production_date_start='1780', production_place='Gorbals, Glasgow, Scotland')
#
# Pandas(Index=79, ID='2.64', creator='Spinks & Co.', current_location='Hill House / Dining Room', description='A round silver punch bowl with brimmed lip, an embossed leaf motif and tiered foot. The bowl is engraved with "Presented to Brother Mason James Honeyman Henderson, 3rd Seaforth Highlander 18th of December 1900" and makers mark "Spink & Son. London."', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1900', production_date_start='1900', production_place='London')
#
# Pandas(Index=124, ID='2.114.1', creator='National Trust for Scotland', current_location='Hill House / Upper Hall / Linen Cupboard A / Shelf 1', description="A heavy cream cotton pencil skirt inspired by Charles Rennie Mackintosh. In the middle of the front is the Mackintosh rose in pink cotton, flanked on either side by the ladies depicted in the panels at either side of the bed in the White Bedroom in orange. On the left side there is an invisible cream plastic zip. The skirt is lined with beige synthetic material. A label sewn into the waist reads: 'Hand Made by the WSC Team, National Trust for Scotland'. The skirt is machine stitched in black thread.", object_category='Household Textiles', object_name='Skirt', production_date_end='1983', production_date_start='1983', production_place='Cramond House')
#
# Pandas(Index=125, ID='2.114.2', creator='National Trust for Scotland', current_location='Hill House / Upper Hall / Linen Cupboard A / Shelf 1', description='A cream cotton blouse inspired by Charles Rennie Mackintosh The blouse is plain except for a black satin ladder type design around the sleeves and collar. Square neckline with additional black satin straps next to the shoulders. The ladder motif is possibly inspired by the chairs in the White Bedroom.', object_category='Household Textiles', object_name='Blouse', production_date_end='1983', production_date_start='1983', production_place='Cramond House')
#
# Pandas(Index=126, ID='2.114.3', creator='National Trust for Scotland', current_location='Hill House / Upper Hall / Linen Cupboard A / Shelf 1', description='A cream cotton hat inspired by Charles Rennie Mackintosh and made to match the blouse. A boat-shaped cap, similar to Glengarry design, with black satin border at the bottom and the ladder design at the top. The ladder motif is possibly inspired by the chairs in the White Bedroom.', object_category='Household Textiles', object_name='Hat', production_date_end='1983', production_date_start='1983', production_place='Cramond House')
#
# Pandas(Index=138, ID='2.141.1', creator='Templetons', current_location='Hill House / Lower Hall', description='One of a group of four carpets. A wool carpet made in a Mackintosh style with a beige ground and blue squares in the corners and a line pattern.', object_category='Household Textiles', object_name='Carpet', production_date_end='1999', production_date_start='1900', production_place='Glasgow')
#
# Pandas(Index=139, ID='2.141.2', creator='Templetons', current_location='Hill House / Lower Hall', description='One of a group of four. A wool carpet made in a Mackintosh style with a beige ground and blue squares in the corners and a line pattern.', object_category='Household Textiles', object_name='Carpet', production_date_end='1999', production_date_start='1900', production_place='Glasgow')
#
# Pandas(Index=140, ID='2.141.3', creator='Templetons', current_location='Hill House / Lower Hall', description='One of a group of four. A wool carpet made in a Mackintosh style with a beige ground and blue squares in the corners and a line pattern.', object_category='Household Textiles', object_name='Carpet', production_date_end='1999', production_date_start='1900', production_place='Glasgow')
#
# Pandas(Index=156, ID='2.182.1', creator='Bulpitt & Sons', current_location='Hill House / Bathroom', description='An electric copper kettle that rests on three metal feet with wooden ends. The kettle has a metal handle with wooden grip, and a round lid with wood and metal finial. There is a metal electric plug attached to the bottom. The kettle is embossed with "Patent No 447987."', object_category='Cooking, Dining and Drinking', object_name='Kettle', production_date_end='1999', production_date_start='1900', production_place='Birmingham')
#
# Pandas(Index=157, ID='2.182.2', creator='Bulpitt & Sons', current_location='Hill House / Bathroom', description='An electric copper kettle that rests on three copper feet with plastic ends. The kettle has a copper handle with a plastic grip, a round lid with a plastic finial and embossed triangular decoration. The kettle has a metal plug attached to the back and the makers\' mark embossed on the bottom: "BULLPITT & SONS BIRMINGHAM; Wolts 240/500 Watts 1500 Pat. No. 447987; Swan brand and patent pending; Made in England."', object_category='Cooking, Dining and Drinking', object_name='Kettle', production_date_end='1999', production_date_start='1900', production_place='Birmingham')
#
# Pandas(Index=161, ID='2.191', creator='Unknown', current_location='Hill House / Dressing Room', description='Oval silver plated hair brush with a flat rim around the edge, inverted curve in the centre, beige coloured fibres (probably horse hair) and illegible hall marks around the edge.', object_category='Toiletry', object_name='Brush', production_date_end='1929', production_date_start='1900', production_place='Birmingham')
#
# Pandas(Index=166, ID='2.197.2', creator='W. Thomson, Hatter & Glover', current_location='Hill House / Dressing Room / Chest of Drawers', description="A long wooden brush with black bristles, possibly a hat brush. The whole brush has a slight inverted curve. Along the top of the brush is written: 'W. Thomson, Hatter & Glover, Lothian Road, Edinburgh.'", object_category='Toiletry', object_name='Brush', production_date_end='1929', production_date_start='1900', production_place='Edinburgh')
#
# Pandas(Index=227, ID='2.234', creator='Unknown', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.4', description='A small bowl with two flat triangular handles with red decoration and a red rim. The body of the porringer is decorated  with a hand painted cockerel and floral sprays.', object_category='Cooking, Dining and Drinking', object_name='Porringer', production_date_end='1929', production_date_start='1900', production_place='Fife')
#
# Pandas(Index=278, ID='2.24', creator='William Adams and Sons Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.4', description='A white rectangular ceramic plate with a blue Chinese inspired decoration. On the reverse of the plate is the maker\'s mark "Rd No. 623294"', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1913', production_date_start='1913', production_place='Tunstall')
#
# Pandas(Index=280, ID='2.241.2', creator='Cauldon Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='Round plain cream ceramic dinner plate with green initials "W. B." painted in a floral motif on the front. "Cauldon England" is stamped on the bottom.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='England')
#
# Pandas(Index=281, ID='2.241.3', creator='Cauldon Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='Round plain cream ceramic soup bowl with green initials "W. B." painted in a floral motif on the front. "Cauldon England" is stamped on the bottom.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1929', production_date_start='1900', production_place='England')
#
# Pandas(Index=282, ID='2.241.4', creator='Cauldon Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='Round plain cream ceramic soup bowl with green initials "W. B." painted in a floral motif on the front. "Cauldon England" is stamped on the bottom.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1929', production_date_start='1900', production_place='England')
#
# Pandas(Index=283, ID='2.241.5', creator='Cauldon Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='Round plain cream ceramic soup bowl with green initials "W. B." painted in a floral motif on the front. "Cauldon England" is stamped on the bottom.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1929', production_date_start='1900', production_place='England')
#
# Pandas(Index=284, ID='2.241.6', creator='Cauldon Ltd', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='Round plain cream ceramic soup bowl with green initials "W. B." painted in a floral motif on the front. "Cauldon England" is stamped on the bottom.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1929', production_date_start='1900', production_place='England')
#
# Pandas(Index=304, ID='2.250.2', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A vegetable tureen made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. The lid is oval in shape with a moulded finial, scalloped edge, gold rim and green floral decoration on cream ground. The body of the tureen is oval in shape with green floral decoration on cream ground with a gold rim, two moulded handles and a raised foot. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Tureen', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=305, ID='2.250.3', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A vegetable tureen made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. The lid is oval in shape with a moulded finial, scalloped edge, gold rim and green floral decoration on cream ground. The body of the tureen is oval in shape with green floral decoration on cream ground with a gold rim, two moulded handles and a raised foot. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Tureen', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=306, ID='2.250.4', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A sauce boat made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Oval shaped body, scalloped edge, raised foot, moulded loop handle, pointed spout and green floral decoration on cream ground with a gold rim. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Sauce Boat', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=307, ID='2.250.5', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='An oval plate for the sauce boat to rest on made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=308, ID='2.250.6', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An oval ashet made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=309, ID='2.250.7', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An oval ashet made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=310, ID='2.250.8', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An oval ashet made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=311, ID='2.250.9', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An oval ashet made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=312, ID='2.250.10', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An oval ashet made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=313, ID='2.250.11', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=314, ID='2.250.12', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=315, ID='2.250.13', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=316, ID='2.250.14', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=317, ID='2.250.15', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=318, ID='2.250.16', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='An dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=319, ID='2.250.17', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=320, ID='2.250.18', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=321, ID='2.250.19', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=322, ID='2.250.20', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=323, ID='2.250.21', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=324, ID='2.250.22', creator='Keeling & Co.', current_location='Hill House / Kitchen', description='A dinner plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=325, ID='2.250.23', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=326, ID='2.250.24', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=327, ID='2.250.25', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=328, ID='2.250.26', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=329, ID='2.250.27', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=330, ID='2.250.28', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1800', production_place='Burslem')
#
# Pandas(Index=331, ID='2.250.29', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=332, ID='2.250.30', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=333, ID='2.250.31', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=334, ID='2.250.33', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=335, ID='2.250.34', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A soup bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=336, ID='2.250.35', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=337, ID='2.250.36', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=338, ID='2.250.37', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=339, ID='2.250.38', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=340, ID='2.250.39', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=341, ID='2.250.40', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=342, ID='2.250.41', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=343, ID='2.250.42', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=344, ID='2.250.43', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=345, ID='2.250.44', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=346, ID='2.250.45', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=347, ID='2.250.46', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A dessert bowl made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=348, ID='2.250.47', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=349, ID='2.250.48', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=350, ID='2.250.49', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=351, ID='2.250.50', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=352, ID='2.250.51', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=353, ID='2.250.52', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=354, ID='2.250.53', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=355, ID='2.250.54', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the bowl on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=356, ID='2.250.55', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=357, ID='2.250.56', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=358, ID='2.250.57', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=359, ID='2.250.58', creator='Keeling & Co.', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='A side plate made by Keeling & Co. in the Gloucester pattern, part of a dinner service set. Scalloped edge, gold rim and green floral pattern on the edge and centre of the plate on cream ground. On the bottom is the maker\'s mark: "RoNo 104604" in a ribbon design with "Gloucester K & Co" written underneath.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1899', production_date_start='1870', production_place='Burslem')
#
# Pandas(Index=360, ID='2.251.1', creator='Gordon B. Bros', current_location='Hill House / Kitchen', description="An oval ceramic soup tureen with two handles and a separate lid. The lid has a round ceramic finial and space for a ladle, and the tureen has fluted edges. Both are decorated in gold and green on cream ground, with geometric shapes, flowers and birds depicted and a brown and red branch detail on the edges. No maker's mark.", object_category='Cooking, Dining and Drinking', object_name='Tureen', production_date_end='1999', production_date_start='1900', production_place='Gloucester')
#
# Pandas(Index=361, ID='2.251.2', creator='Gordon B. Bros', current_location='Hill House / Kitchen', description="An oval ceramic vegetable tureen with two handles and a separate lid. The lid has a round ceramic finial and space for a ladle, and the tureen has fluted edges. Both are decorated in gold and green on cream ground, with geometric shapes, flowers and birds depicted and a brown and red branch detail on the edges. No maker's mark.", object_category='Cooking, Dining and Drinking', object_name='Tureen', production_date_end='1999', production_date_start='1900', production_place='Gloucester')
#
# ...
#
# Pandas(Index=423, ID='2.255.7', creator='Grimwade', current_location='Hill House / Kitchen', description='One of a set of seven storage jars. A round porcelain storage jar in cream. There is a ribbed effect on the jar and the word "Rice" stamped in green.', object_category='Cooking, Dining and Drinking', object_name='Storage Jar', production_date_end='0000', production_date_start='0000', production_place='Stoke-on-Trent')
#
# Pandas(Index=453, ID='2.260.1', creator='Eismarck', current_location="Hill House / Butler's Pantry", description='An oval ceramic ashet in a cream ground and decorated with pink, blue and green garlands. On the reverse is the maker\'s mark stamped "EISMARK AND SONS, ENGLAND" over a crest.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1999', production_date_start='1900', production_place='England')
#
# Pandas(Index=454, ID='2.260.2', creator='Eismarck', current_location="Hill House / Butler's Pantry", description='An oval ceramic ashet in a cream ground and decorated with pink, blue and green garlands. On the reverse is the maker\'s mark stamped "EISMARK AND SONS, ENGLAND" over a crest.', object_category='Cooking, Dining and Drinking', object_name='Ashet', production_date_end='1999', production_date_start='1900', production_place='England')
#
# Pandas(Index=455, ID='2.261', creator='Unknown', current_location="Hill House / Butler's Pantry", description='An oval ceramic ashet with a raised scalloped edge. The ashet is cream with two bands of cobalt blue decoration in an Asian inspired design and a matching circular decoration in the centre of the dish.', object_category='Cooking, Dining and Drinking', object_name='Dish', production_date_end='1899', production_date_start='1800', production_place='Staffordshire')
#
# Pandas(Index=456, ID='2.262', creator='Royal Crown Derby', current_location='Hill House / Room off Tea Room', description='oval, with plain bl flowerhead pattern', object_category='Cooking, Dining and Drinking', object_name='Meat Plate', production_date_end='0000', production_date_start='0000', production_place='Derby')
#
# Pandas(Index=475, ID='2.1510.1', creator='Judge Ware', current_location='Hill House / Kitchen', description='Black enamelled metal cooking pot with lid. The lid is metal with a square handle. The pot has a handle which sits at a 45 degree angle and widens towards the end and has a circular cover on the end. There is a makers mark on the body of the pot, an oval with the words "No 3 FALKIRK 4 PNTS" embossed.', object_category='Cooking, Dining and Drinking', object_name='Cooking Pot', production_date_end='0000', production_date_start='0000', production_place='Bristol')
#
# Pandas(Index=518, ID='80.1508.1', creator='Adams, W. S. & Son', current_location='Hill House / Kitchen', description='One of a set of two jelly moulds. A Circular copper jelly mould. The mould has the engraving "W.S Adams and Son, ironmongers to the Queen, 57 Haymarket."', object_category='Cooking, Dining and Drinking', object_name='Jelly Mould', production_date_end='0000', production_date_start='0000', production_place='57 Haymarket')
#
# Pandas(Index=519, ID='80.1508.2', creator='Adams, W. S. & Son', current_location='Hill House / Kitchen', description='One of a set of two jelly moulds. A Circular copper jelly mould. The mould has the engraving "W.S Adams and Son, ironmongers to the Queen, 57 Haymarket."', object_category='Cooking, Dining and Drinking', object_name='Jelly Mould', production_date_end='0000', production_date_start='0000', production_place='57 Haymarket')
#
# Pandas(Index=520, ID='86.5', creator='J. Moyes', current_location='Hill House / Library', description='A pewter tankard with an attached lid, looped handle, stepped foot and a baluster shaped body. The tankard is stamped with "HALF PINT" and under the lid is the makers mark "J. MOYES EDINBURGH."', object_category='Cooking, Dining and Drinking', object_name='Tankard', production_date_end='1869', production_date_start='1830', production_place='Edinburgh')
#
# Pandas(Index=527, ID='88.144.24', creator='Unknown', current_location='Hill House / White Bedroom', description="A silver backed hair brush with beige bristles, possibly horse hair. Stylised Art Nouveau design on the back.  The hall marks are very faint with only 'S and Co' showing with the duty marks.", object_category='Toiletry', object_name='Hair Brush', production_date_end='1999', production_date_start='1900', production_place='Birmingham')
#
# Pandas(Index=528, ID='88.144.25', creator='Unknown', current_location='Hill House / White Bedroom', description="A silver backed hand held mirror. The hall marks are very faint with only 'S and Co' showing with the duty marks. There is a stylised Art Nouveau design on the back.", object_category='Toiletry', object_name='Mirror', production_date_end='1999', production_date_start='1900', production_place='Birmingham')
#
# Pandas(Index=549, ID='91.79.1', creator='Unknown', current_location="Hill House / Butler's Pantry", description='A salt glazed stoneware jug with a fluted body, round base and looped handle. Repousse decoration of men drinking and smoking, a windmill and a hunt scene.  Inscribed with stamp: "Old Will 1761" and "They may talk about the income tax but give me XX" with hunt scene round base. The maker\'s mark is: "Grosvenor Glasgow".', object_category='Decorative Arts', object_name='Jug', production_date_end='0000', production_date_start='0000', production_place='Glasgow')
#
# Pandas(Index=579, ID='2011.808', creator='Mackintosh, Charles Rennie', current_location='Hill House / Guest Bedroom', description='An oak press wardrobe circa 1894 with moulded and projecting cornice above twin doors with fielded panels and applied decorative strap hinges over a central drawer flanked with two short drawers, each with patinated steel drop handles, and rests on raised short square legs.', object_category='Furniture and Furnishings', object_name='Wardrobe', production_date_end='1894', production_date_start='1894', production_place='Glasgow')
#
# Pandas(Index=607, ID='2017.4008.1', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped  in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=608, ID='2017.4008.2', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped  in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=609, ID='2017.4008.3', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=610, ID='2017.4008.4', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=611, ID='2017.4008.5', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=612, ID='2017.4008.6', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=613, ID='2017.4008.7', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=614, ID='2017.4008.8', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=615, ID='2017.4008.9', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=616, ID='2017.4008.10', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=617, ID='2017.4008.11', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=618, ID='2017.4008.12', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic side plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=619, ID='2017.4008.13', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic side plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=620, ID='2017.4008.14', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic side plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=621, ID='2017.4008.15', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic side plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=622, ID='2017.4008.16', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic bowl with blue floral decoration and ribbed rim. On the bottom of the bowl a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Bowl', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=623, ID='2017.4008.17', creator='Furnival', current_location='Hill House / Flower Pantry / Cupboard 2017.4032.2', description='White ceramic serving plate with blue floral decoration and ribbed rim. On the bottom of the plate a viking boat is stamped in blue along with "Denmark, Furnival Limited", "England, Made in England"in blue lettering.', object_category='Cooking, Dining and Drinking', object_name='Plate', production_date_end='1929', production_date_start='1900', production_place='Denmark')
#
# Pandas(Index=845, ID='2017.4198', creator='Cockburn J F', current_location='Hill House / Attic', description='A round ceramic salt glaze storage jar with lid. The lid has a slight curve to it with a round finial and is decorated with a dot motif. The jar has a raised lip with two shallow handles. The handles are moulded to resemble a lion head with a hoop in its mouth. The lid and the neck of the jar are in a brown glaze with the remainder of the body in a beige glaze. The neck of the body is decorated with a dot relief. On one side of the body the words "J. F. COCKBURN EDINBURGH" are carved. Underneath one of the handles is the number "8."', object_category='Cooking, Dining and Drinking', object_name='Storage Jar', production_date_end='0000', production_date_start='0000', production_place='Edinburgh')

# %%
sub_df.set_index('ID') # doesn't seem to have worked...
sub_df.tail()
# Out:
#               ID         creator  \
# 846      2017.42         Unknown
# 847    2017.4245  Rickey, George
# 848    2017.4247         Unknown
# 849  2017.4248.1         Unknown
# 850  2017.4248.2         Unknown
#
#                                       current_location  \
# 846                         Hill House / Flower Pantry
# 847                             Hill House / Cloakroom
# 848                       Hill House / Butler's Pantry
# 849  Hill House / Upper Hall / Linen Cupboard B / D...
# 850  Hill House / Upper Hall / Linen Cupboard B / D...
#
#                                            description  \
# 846  An oval wicker flower basket with a round hand...
# 847  Sections of an outdoor stainless steel kinetic...
# 848  A ceramic salt glaze storage jar with a raised...
# 849  One of a set of two curtains in cream cotton, ...
# 850  One of a set of two curtains in cream cotton, ...
#
#                   object_category  object_name production_date_end  \
# 846                 Miscellaneous       Basket                1929
# 847                     Sculpture    Sculpture                1996
# 848  Cooking, Dining and Drinking  Storage Jar                1929
# 849            Household Textiles      Curtain                0000
# 850            Household Textiles      Curtain                0000
#
#     production_date_start production_place
# 846                  1900          Unknown
# 847                  1996          Unknown
# 848                  1900          Unknown
# 849                  0000          Unknown
# 850                  0000          Unknown

# %%
import numpy as np

#print(sub_df.iloc[0, 2])
#current_location_count = pd.Series(sub_df.current_location).value_counts()
c_l, c_l_counts = np.unique(sub_df.current_location, return_counts=True)
c_l_dict = dict(zip(c_l, c_l_counts))
print("Count of Current Locations:")
print(c_l_dict)
#print(c_l_dict.keys())
#print()
#print(list(c_l_dict.values()))
# Out:
# Count of Current Locations:
# {'Hill House / Attic': 85, 'Hill House / Bathroom': 5, "Hill House / Butler's Pantry": 52, 'Hill House / Cloakroom': 1, "Hill House / Daughter's Bedroom": 7, 'Hill House / Dining Room': 61, 'Hill House / Drawing Room': 31, 'Hill House / Dressing Room': 10, 'Hill House / Dressing Room / Chest of Drawers': 6, 'Hill House / Flower Pantry': 4, 'Hill House / Flower Pantry / Cupboard 2017.4032.1': 49, 'Hill House / Flower Pantry / Cupboard 2017.4032.2': 109, 'Hill House / Flower Pantry / Cupboard 2017.4032.4': 46, 'Hill House / Guest Bedroom': 1, 'Hill House / Kitchen': 134, 'Hill House / Kitchen / Cupboard 2017.4034': 12, 'Hill House / Library': 40, 'Hill House / Linen Cupboard A / Silver Strong Room / Shelf 1': 1, 'Hill House / Lower Hall': 18, 'Hill House / Main Stair': 1, 'Hill House / Night Nursery': 1, 'Hill House / Room off Tea Room': 1, 'Hill House / See Separate Records for Locations of Parts': 15, 'Hill House / Staircase / Upper Hall': 1, 'Hill House / Upper Hall': 3, 'Hill House / Upper Hall / Linen Cupboard A / Shelf 1': 26, 'Hill House / Upper Hall / Linen Cupboard A / Shelf 2': 27, 'Hill House / Upper Hall / Linen Cupboard A / Shelf 3': 13, 'Hill House / Upper Hall / Linen Cupboard A / Shelf 4': 2, 'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 1': 2, 'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 2': 2, 'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 3': 4, 'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 4': 4, 'Hill House / Upper Hall / Linen Cupboard A / Silver Strong Room / Shelf 5': 2, 'Hill House / Upper Hall / Linen Cupboard B / Drawer 4': 11, 'Hill House / Upper Hall / Linen Cupboard B / Drawer 5': 1, 'Hill House / Upper Hall / Silver Strong Room / Linen Cupboard A / Shelf 6': 2, 'Hill House / White Bedroom': 26, 'Holidays / Hill House': 35}

# %%
p_p, p_p_counts = np.unique(sub_df.production_place, return_counts=True)
p_p_dict = dict(zip(p_p, p_p_counts))
print("Count of Production Places:")
print(p_p_dict)
print()
c, c_counts = np.unique(sub_df.creator, return_counts=True)
c_dict = dict(zip(c, c_counts))
print("Count of Creators:")
print(c_dict)
# Out:
# Count of Production Places:
# {'57 Haymarket': 2, 'Arundel, Sussex, England': 2, 'Birmingham': 5, 'Bristol': 1, 'Burslem': 56, 'Cramond House': 3, 'Denmark': 17, 'Derby': 1, 'Edinburgh': 3, 'England': 7, 'Fife': 1, 'Glasgow': 25, 'Gloucester': 23, 'Gorbals': 1, 'Gorbals, Glasgow, Scotland': 3, 'Halifax': 1, 'London': 1, 'Staffordshire': 1, 'Stoke-on-Trent': 7, 'Tunstall': 1, 'Unknown': 690}
#
# Count of Creators:
# {'Adams, W. S. & Son': 2, 'Avena Carpets': 1, 'Blackie, Alison': 9, 'Broadwood, John & Sons': 1, 'Bulpitt & Sons': 2, 'Cauldon Ltd': 6, 'Cockburn J F': 1, 'Copeland Spode': 1, 'Copeland and Garrett': 1, 'Craig, John': 9, 'Dallas, Mr': 2, "Dr Gemmell's mother": 1, 'Dresser, Christopher': 1, 'Eismarck': 2, 'Ewbank': 1, 'Fergusson, John Duncan': 1, 'Figgjo': 4, 'Furnival': 17, 'G. T. M.': 47, 'Gordon B. Bros': 43, 'Gray F Portobello': 5, 'Grimwade': 7, 'Grosvenor Eagle Pottery Glasgow': 1, 'Hartley': 1, 'Haviland & Co Limoges': 28, 'Heathcote China': 8, 'Helpmate': 6, 'Henry, George': 1, 'Hilliard, Terence': 8, 'Hoover Company': 12, 'J. Moyes': 1, 'Jack, William': 5, 'John Blacksmith, Allan': 1, 'John Broadwood & Sons': 1, 'Judge Ware': 5, 'Kayserzinn': 1, 'Keeling & Co.': 56, 'Liberty & Co.': 1, 'MacDonald, Margaret': 7, 'Mackintosh, Charles Rennie': 81, 'Mackintosh, Margaret Macdonald': 2, 'Martin, Alex': 7, 'Mitchell, Alexander': 4, 'Morris, Talwyn': 1, 'National Trust for Scotland': 3, 'Pringle, John Quinton': 2, 'Raeburn, Henry (FRSE, RA)': 1, 'Rickey, George': 1, 'Royal Crown Derby': 37, 'Royal Worcester': 17, 'Spinks & Co.': 1, 'Steelite': 3, 'Strain, Hilary': 1, 'Tala': 1, 'Tala Cookware': 7, 'Templetons': 3, 'Unknown': 339, 'W. Thomson, Hatter & Glover': 1, 'Wedgwood': 27, 'William Adams and Sons Ltd': 1, 'William McClymont': 1, 'Younger, Jane': 3}

# %%
drawing_room_objects = []
for row in sub_df.itertuples():
    loc = (str(row[3]).lower())
    if "drawing room" in loc:
        drawing_room_objects += [[row[1], row[6]]]

#for o in drawing_room_objects:
    #print(o)
    #print()
print("Number of Objects in the Drawing Room: " + str(len(drawing_room_objects)))
# Out:
# Number of Objects in the Drawing Room: 31

# %% [markdown]
# # Data Visualization Drafts
#
# Data visualizations for 4 themes: creator, product date (start & end), current location, and production place

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# From https://seaborn.pydata.org/examples/color_palettes.html
#f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 6), sharex=True)

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 20), sharex=False)

# Visualize the number of objects in each Hill House room
x1 = list(c_l_dict.keys())
y1 = list(c_l_dict.values())
g1 = sns.barplot(x1, y1, palette="Set1", ax=ax1)
ax1.set_xlabel("Room in Hill House")
g1.set_xticklabels("Room in Hill House", rotation=30)
ax1.set_ylabel("Number of Objects")

# Visualize the number of objects in each production place
x2 = list(p_p_dict.keys())
y2 = list(p_p_dict.values())
g2 = sns.barplot(x2, y2, palette="Set2", ax=ax2).set_xticklabels(rotation=30)
ax2.set_xlabel("Production Place")
g2.set_xticklabels("Production Place", rotation=30)
ax2.set_ylabel("Number of Objects")

# Visualize the number of objects made by each creator
x3 = list(c_dict.keys())
y3 = list(c_dict.values())
g3 = sns.barplot(x3, y3, palette="Set3", ax=ax3).set_xticklabels(rotation=30)
ax3.set_xlabel("Creator")
g3.set_xticklabels("Creator", rotation=30)
ax3.set_ylabel("Number of Objects")

# Visualize the number of objects each creator made
# Set appearance of plots
#sns.despine(bottom=True)
plt.title("Hill House Object Counts")
#plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-c9cf1da65e01> in <module>()
#       7 x1 = list(c_l_dict.keys())
#       8 y1 = list(c_l_dict.values())
# ----> 9 sns.barplot(x1, y1, palette="Set1", ax=ax1).set_xticklabels(rotation=30)
#      10 ax1.set_xlabel("Room in Hill House")
#      11 ax1.set_ylabel("Number of Objects")
#
# TypeError: set_xticklabels() missing 1 required positional argument: 'labels'
